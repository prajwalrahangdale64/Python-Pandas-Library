# %% [markdown]
# # Introduction to Pandas
#
# In this section of the course we will learn how to use pandas for data analysis. We can think of pandas as an extremely powerful version of Excel, with a lot more features. In this section of the course, we should go through the notebooks in this order:
#
# * Introduction to Pandas
# * Series
# * DataFrames
# * Missing Data
# * GroupBy
# * Merging, Joining and Concatenating
# * Operations
# * Data Input and Output

# %% [markdown]
# ___

# %% [markdown]
# - Pandas is an open source library that's built on top of NumPy.

# %% [markdown]
# - It allows for fast analysis and data cleaning and preparation.

# %% [markdown]
# - We can think of pandas as an extremely powerful version of Excel, with a lot more features.

# %% [markdown]
# - It excels in performance and productivity.

# %% [markdown]
# - It has built in data visualization features.

# %% [markdown]
# - It can work with data from a wide variety of sources.

# %% [markdown]
# ---

# %% [markdown]
# - We'll need to install Pandas by going to the command line or terminal and then use either:
#
#         conda install pandas
#
#         pip install pandas
#
# ![Capture4.PNG](attachment:73086ea4-7cbc-426c-95a9-b31eb3ebe720.PNG)

# %% [markdown]
# ---
